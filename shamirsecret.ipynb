# %%
import random

# %%
k = 2

# %%
n = 6

# %%
secret = 1234

# %%
a = random.randint(-5, 5)
print("Nombre aléatoire a =", a)
# Out:
# Nombre aléatoire a = 1

# %%
parts = []
for x in range(1, n + 1):
    y = secret + a * x 
    parts.append((x, y))

# %%
print("\nParts distribuées :")
for part in parts:
    print(part)
# Out:
# Parts distribuées :
# (1, 1235)
# (2, 1236)
# (3, 1237)
# (4, 1238)
# (5, 1239)
# (6, 1240)
